# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.6.1

# %%
import pandas as pd
import numpy as np

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
iris_dataset = load_iris()
df = pd.DataFrame(iris_dataset.data, columns=iris_dataset.feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df['petal length (cm)']
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: petal length (cm), Length: 150, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X = df.drop('petal length (cm)', axis=1)
y = df['petal length (cm)']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 40)

# %%
X_train
# Out:
#     sepal length (cm)  sepal width (cm)  petal width (cm)
# 62                6.0               2.2               1.0
# 23                5.1               3.3               0.5
# 26                5.0               3.4               0.4
# 48                5.3               3.7               0.2
# 2                 4.7               3.2               0.2
# ..                ...               ...               ...
# 71                6.1               2.8               1.3
# 12                4.8               3.0               0.1
# 50                7.0               3.2               1.4
# 7                 5.0               3.4               0.2
# 70                5.9               3.2               1.8
#
# [120 rows x 3 columns]

# %%
X_test
# Out:
#      sepal length (cm)  sepal width (cm)  petal width (cm)
# 38                 4.4               3.0               0.2
# 66                 5.6               3.0               1.5
# 115                6.4               3.2               2.3
# 117                7.7               3.8               2.2
# 89                 5.5               2.5               1.3
# 136                6.3               3.4               2.4
# 68                 6.2               2.2               1.5
# 94                 5.6               2.7               1.3
# 84                 5.4               3.0               1.5
# 28                 5.2               3.4               0.2
# 90                 5.5               2.6               1.2
# 11                 4.8               3.4               0.2
# 40                 5.0               3.5               0.3
# 126                6.2               2.8               1.8
# 79                 5.7               2.6               1.0
# 144                6.7               3.3               2.5
# 123                6.3               2.7               1.8
# 124                6.7               3.3               2.1
# 76                 6.8               2.8               1.4
# 59                 5.2               2.7               1.4
# 132                6.4               2.8               2.2
# 105                7.6               3.0               2.1
# 53                 5.5               2.3               1.3
# 17                 5.1               3.5               0.3
# 64                 5.6               2.9               1.3
# 18                 5.7               3.8               0.3
# 13                 4.3               3.0               0.1
# 116                6.5               3.0               1.8
# 9                  4.9               3.1               0.1
# 81                 5.5               2.4               1.0

# %%
y_test
# Out:
# 38     1.3
# 66     4.5
# 115    5.3
# 117    6.7
# 89     4.0
# 136    5.6
# 68     4.5
# 94     4.2
# 84     4.5
# 28     1.4
# 90     4.4
# 11     1.6
# 40     1.3
# 126    4.8
# 79     3.5
# 144    5.7
# 123    4.9
# 124    5.7
# 76     4.8
# 59     3.9
# 132    5.6
# 105    6.6
# 53     4.0
# 17     1.4
# 64     3.6
# 18     1.7
# 13     1.1
# 116    5.5
# 9      1.5
# 81     3.7
# Name: petal length (cm), dtype: float64

# %%
y_train
# Out:
# 62    4.0
# 23    1.7
# 26    1.6
# 48    1.5
# 2     1.3
#      ...
# 71    4.0
# 12    1.4
# 50    4.7
# 7     1.5
# 70    4.8
# Name: petal length (cm), Length: 120, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
s = StandardScaler()
X_train_scaled = s.fit_transform(X_train)
X_test_scaled = s.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[ 0.17933237, -1.9885443 , -0.23382732],
#        [-0.90875166,  0.51372308, -0.89249581],
#        [-1.02964989,  0.74120193, -1.02422951],
#        [-0.66695521,  1.42363849, -1.28769691],
#        [-1.39234456,  0.28624422, -1.28769691],
#        [ 0.66292527, -0.62367119,  1.21524337],
#        [-1.51324279,  0.74120193, -1.15596321],
#        [-1.75503924,  0.28624422, -1.28769691],
#        [-0.18336231, -1.30610775,  1.08350967],
#        [-0.18336231,  3.01599045, -1.02422951],
#        [-1.51324279,  0.05876537, -1.28769691],
#        [ 1.02561995,  0.05876537,  0.42484118],
#        [ 0.30023059, -0.16871348,  0.82004227],
#        [ 1.50921285, -0.16871348,  1.21524337],
#        [ 1.63011107,  0.28624422,  0.82004227],
#        [-0.90875166,  0.74120193, -1.28769691],
#        [ 2.2346022 , -1.07862889,  1.47871077],
#        [ 0.17933237, -0.16871348,  0.82004227],
#        [ 1.02561995, -1.30610775,  0.82004227],
#        [-0.06246408, -0.85115004,  0.02964008],
#        [-0.54605698,  0.74120193, -1.02422951],
#        [-0.90875166, -1.30610775, -0.10209362],
#        [-1.15054811, -1.30610775,  0.68830858],
#        [-1.02964989,  0.28624422, -1.28769691],
#        [-1.02964989,  0.96868078, -0.76076211],
#        [-0.30426053, -0.62367119,  1.08350967],
#        [ 0.54202704, -1.76106545,  0.16137378],
#        [-0.90875166,  1.65111734, -1.28769691],
#        [-0.90875166,  1.65111734, -1.02422951],
#        [-1.02964989, -2.44350201, -0.23382732],
#        [-1.27144634,  0.05876537, -1.28769691],
#        [ 1.2674164 ,  0.05876537,  1.47871077],
#        [-0.18336231, -0.62367119,  0.16137378],
#        [ 2.47639865,  1.65111734,  1.08350967],
#        [-1.51324279,  1.19615963, -1.28769691],
#        [ 0.78382349, -0.16871348,  1.34697707],
#        [-0.06246408, -1.07862889,  0.02964008],
#        [-0.06246408,  2.10607504, -1.28769691],
#        [-1.75503924, -0.39619233, -1.28769691],
#        [ 1.2674164 ,  0.05876537,  1.21524337],
#        [-1.02964989,  0.51372308, -1.28769691],
#        [ 0.30023059, -0.62367119,  0.02964008],
#        [ 0.30023059, -0.16871348,  0.29310748],
#        [-0.18336231, -0.62367119,  0.16137378],
#        [ 0.66292527, -0.39619233,  0.16137378],
#        [-0.90875166,  1.65111734, -1.15596321],
#        [-0.06246408, -0.62367119,  1.61044447],
#        [ 0.30023059, -0.62367119,  0.16137378],
#        [-1.27144634, -0.16871348, -1.4194306 ],
#        [ 1.38831462,  0.28624422,  0.29310748],
#        [-1.02964989,  0.74120193, -1.28769691],
#        [ 0.05843414,  0.28624422,  0.82004227]])

# %%
X_test_scaled
# Out:
# array([[-1.75503924, -0.16871348, -1.28769691],
#        [-0.30426053, -0.16871348,  0.42484118],
#        [ 0.66292527,  0.28624422,  1.47871077],
#        [ 2.2346022 ,  1.65111734,  1.34697707],
#        [-0.42515876, -1.30610775,  0.16137378],
#        [ 0.54202704,  0.74120193,  1.61044447],
#        [ 0.42112882, -1.9885443 ,  0.42484118],
#        [-0.30426053, -0.85115004,  0.16137378],
#        [-0.54605698, -0.16871348,  0.42484118],
#        [-0.78785344,  0.74120193, -1.28769691],
#        [-0.42515876, -1.07862889,  0.02964008],
#        [-1.27144634,  0.74120193, -1.28769691],
#        [-1.02964989,  0.96868078, -1.15596321],
#        [ 0.42112882, -0.62367119,  0.82004227],
#        [-0.18336231, -1.07862889, -0.23382732],
#        [ 1.02561995,  0.51372308,  1.74217817],
#        [ 0.54202704, -0.85115004,  0.82004227],
#        [ 1.02561995,  0.51372308,  1.21524337],
#        [ 1.14651817, -0.62367119,  0.29310748],
#        [-0.78785344, -0.85115004,  0.29310748],
#        [ 0.66292527, -0.62367119,  1.34697707],
#        [ 2.11370397, -0.16871348,  1.21524337],
#        [-0.42515876, -1.76106545,  0.16137378],
#        [-0.90875166,  0.96868078, -1.15596321],
#        [-0.30426053, -0.39619233,  0.16137378],
#        [-0.18336231,  1.65111734, -1.15596321],
#        [-1.87593746, -0.16871348, -1.4194306 ],
#        [ 0.78382349, -0.16871348,  0.82004227],
#        [-1.15054811,  0.05876537, -1.4194306 ],
#        [-0.42515876, -1.5335866 , -0.23382732]])

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

y_pred = lr.predict(X_test_scaled)

print("Mean Squared Error (MSE):", mean_squared_error(y_test, y_pred))
print("Mean Absolute Error (MAE):", mean_absolute_error(y_test, y_pred))
print("R² Score:", r2_score(y_test, y_pred))
# Out:
# Mean Squared Error (MSE): 0.09083848190367848
# Mean Absolute Error (MAE): 0.24390430935924337
# R² Score: 0.9683147365085358

# %%
import matplotlib.pyplot as plt

plt.scatter(y_test, y_pred, color='blue')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linewidth=2)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs Predicted (Linear Regression)")
plt.show()
